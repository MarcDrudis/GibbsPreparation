# %%
from gibbs.preparation.varqite import efficientTwoLocalansatz
from qiskit import transpile
from qiskit import QuantumCircuit
from qiskit.providers.fake_provider import FakeMelbourne,FakeAuckland, FakeMontreal, FakeSherbrooke
import numpy as np
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
backend = FakeSherbrooke()
print(backend.operation_names)
ansatz_arguments = {"num_qubits":3,"depth":1,"entanglement":"reverse_linear","su2_gates":["rz"],"ent_gates":["rzx","rx","rzx"]}
qc,x0 = efficientTwoLocalansatz(**ansatz_arguments)
display(qc.decompose().draw(output="mpl"))

qc_basis = transpile(qc, backend)
# display(qc_basis.draw(output='mpl'))
print(qc_basis.depth(),qc_basis.size(),qc_basis.num_parameters)
# Out:
# ['rz', 'sx', 'x', 'ecr', 'measure', 'delay']
# 71 175 28

# %%
from qiskit.circuit.library import TwoLocal, ECRGate
qc = TwoLocal(3,["rz"],[ECRGate()],insert_barriers=True,entanglement="reverse_linear")
print(qc_basis.depth(),qc_basis.size(),qc_basis.num_parameters)
display(qc.decompose().draw(output="mpl"))
qc_basis = transpile(qc, backend)
display(qc_basis.draw(output='mpl'))
# Out:
# 44 102 12
