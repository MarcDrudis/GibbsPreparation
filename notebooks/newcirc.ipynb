# %%
from gibbs.preparation.varqite import efficientTwoLocalansatz
from qiskit import transpile
from qiskit import QuantumCircuit
from qiskit.providers.fake_provider import FakeMelbourne,FakeAuckland, FakeMontreal
import numpy as np
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
backend = FakeMontreal()
ansatz_arguments = {"num_qubits":4,"depth":2,"entanglement":"reverse_linear","su2_gates":["ry"],"ent_gates":["cx"]}
qc,x0 = efficientTwoLocalansatz(**ansatz_arguments)
display(qc.decompose().draw(output="mpl"))

qc_basis = transpile(qc, backend)
qc_basis = transpile(qc_basis,backend)
display(qc_basis.draw(output='mpl'))
print(qc_basis.depth(),qc_basis.size())
# Out:
# 22 114
